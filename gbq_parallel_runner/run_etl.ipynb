# %% [markdown]
# # Pip Install Requirements

# %%
# %%time

# !pip install --upgrade pip
# !pip install -r requirements.txt

# !pip cache purge

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# gcloud auth login --update-adc --no-launch-browser

# %% [markdown]
# # Define config files
# - base_config.yml should have all the non changing parameters like project_id, dataset_id, gcp_project & (levels of running sql files if there are many)
# - run_config_dir/run_config_<date>_<train_test_score>.yml will have all changing parameters that change each of the different runs

# %%
# %%bash
# # Run this to actually run multiple ETLs in parallel
# # Max 100 ETLs at the same time
# python run_etl_in_levels.py \
#   --all_configs base_config.yml \
#   --max-concurrency 100

# %% [markdown]
# ```bash
#
# pip install --upgrade pip
# pip install -r requirements.txt
#
# pip cache purge
#
# gcloud auth login --update-adc --no-launch-browser
#
# python run_etl_in_levels.py \
#   --all_configs config.yml \
#   --max-concurrency 25
#
# ```
